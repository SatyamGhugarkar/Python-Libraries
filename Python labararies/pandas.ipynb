# %%
import pandas as pd
import numpy as np

# %%
l = [1,2,3,4]
de = pd.Series(l)

# %%
de
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
[type(de)]
# Out:
# [pandas.core.series.Series]

# %%
df = pd.read_csv("bollywood.csv",index_col ="movie" ).squeeze()
df
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.head(2)
# Out:
# movie
# Uri: The Surgical Strike    Vicky Kaushal
# Battalion 609                 Vicky Ahuja
# Name: lead, dtype: object

# %%
df.sample()
# Out:
# movie
# Bachke Rehna Re Baba    Rekha
# Name: lead, dtype: object

# %%
df.sample(5)
# Out:
# movie
# Dishoom                      John Abraham
# Delhi Safari                   Cary Elwes
# Lekar Hum Deewana Dil         Armaan Jain
# Humpty Sharma Ki Dulhania    Varun Dhawan
# Saathiya (film)              Vivek Oberoi
# Name: lead, dtype: object

# %%
df.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
df.sort_values()
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
df.sort_values(ascending=False)
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Dil Toh Deewana Hai                  Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Fanaa (2006 film)                     Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
#method chaining
df.sort_values(ascending=False).head(1)
df.sort_values(ascending=False).sum()# only numerical data
# Out:
# "Zulfi SayedZeenat AmanZeenat AmanZeenat AmanZeenat AmanZayed KhanZayed KhanZayed KhanZareen KhanZara SheikhZaira WasimZaira WasimZaheer IqbalYudhveer BakoliyaYogesh Raj MishraYashpal SharmaYash SoniYash AcharyaWamiqa GabbiWaheeda RehmanVivek SudershanVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVivek OberoiVishwa Mohan BadolaVira SathidarVir DasVipin SharmaVinod KhannaVinod KhannaVinod KhannaVinod AcharyaVinay VirmaniVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay PathakVinay AnandVikrum KumarVikram DasuVikram AdityaVikas KalantriVikaas KalantariVijay VarmaVijay RaazVijay RaazViineet KumarVidyut JammwalVidyut JammwalVidyut JammwalVidya BalanVidya BalanVidya BalanVidya BalanVidya BalanVidya BalanVictor BanerjeeVictor BanerjeeVicky KaushalVicky KaushalVicky AhujaVicky AhujaVicky AhujaVickrant MahajanVeena MalikVatsal ShethVatsal ShethVarun Dhawan
# ...

# %%
# permanat changing
df=df.copy()
df
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [raw]
# df.sort_value(inplace=True)

# %%
df.sort_values(inplace=True)
df
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
df.sort_index(ascending=True)
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
#indexing
d=pd.Series([1,2,3,4,5,6,7])
d[1]
#d[-1]# negative indexing not allow
#change the value
d[2]=100
d
# Out:
# 0      1
# 1      2
# 2    100
# 3      4
# 4      5
# 5      6
# 6      7
# dtype: int64

# %%
df["Uri: The Surgical Strike"]
# Out:
# 'Vicky Kaushal'
